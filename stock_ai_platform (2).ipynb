# %%
# %%writefile stock_data.py
import yfinance as yf

def get_stock_data(ticker):

    ticker_symbol = ticker + ".NS"

    stock = yf.Ticker(ticker_symbol)

    info = stock.info

    data = {
        "price": info.get("currentPrice"),
        "open": info.get("open"),
        "high": info.get("dayHigh"),
        "low": info.get("dayLow"),
        "volume": info.get("volume")
    }

    return data
# Out:
# Overwriting stock_data.py

# %%
# %%writefile news_fetcher.py
import requests

API_KEY = "YOUR_GNEWS_KEY"

def get_news(company):

    url = f"https://gnews.io/api/v4/search?q={company}&lang=en&apikey={API_KEY}"

    response = requests.get(url)

    articles = response.json()["articles"]

    headlines = []

    for article in articles[:3]:
        headlines.append(article["title"])

    return headlines
# Out:
# Overwriting news_fetcher.py

# %%
# %%writefile ai_summary.py
import requests

API_KEY = "YOUR_GROQ_KEY"

def generate_summary(stock_data, news):

    prompt = f"""
Create a 90 second beginner friendly stock video script.

Stock Data:
Price: {stock_data['price']}
Open: {stock_data['open']}
High: {stock_data['high']}
Low: {stock_data['low']}

News:
{news}

Structure:

Hook (0-10 sec)
Stock Snapshot (10-30 sec)
What's Happening (30-60 sec)
Beginner Takeaway (60-80 sec)
Call to Action (80-90 sec)
"""

    return prompt
# Out:
# Overwriting ai_summary.py

# %%
# %%writefile video_generator.py
from gtts import gTTS
from moviepy.editor import *

def create_video(script):

    tts = gTTS(script)

    tts.save("voice.mp3")

    audio = AudioFileClip("voice.mp3")

    text = TextClip(script, fontsize=28, size=(720,480), method="caption")

    text = text.set_duration(audio.duration)

    video = text.set_audio(audio)

    video.write_videofile("stock_video.mp4")

    return "stock_video.mp4"
# Out:
# Overwriting video_generator.py

# %%
# %%writefile app.py
import streamlit as st

from stock_data import get_stock_data
from news_fetcher import get_news
from ai_summary import generate_summary
from video_generator import create_video

st.title("AI Stock Market Intelligence")

ticker = st.text_input("Enter Stock Ticker")

if st.button("Analyze"):

    stock = get_stock_data(ticker)

    st.write(stock)

    news = get_news(ticker)

    for n in news:
        st.write("-", n)

    script = generate_summary(stock, news)

    st.write(script)

    video = create_video(script)

    st.video(video)
# Out:
# Overwriting app.py

# %%
# !ls
# Out:
# ai_summary.py  news_fetcher.py	stock_data.py
# app.py	       sample_data	video_generator.py

# %%
# !pip install streamlit yfinance gtts moviepy requests

# %%
# %%writefile stock_data.py
import yfinance as yf

def get_stock_data(ticker):

    ticker_symbol = ticker + ".NS"

    stock = yf.Ticker(ticker_symbol)

    info = stock.info

    data = {
        "price": info.get("currentPrice"),
        "open": info.get("open"),
        "high": info.get("dayHigh"),
        "low": info.get("dayLow"),
        "volume": info.get("volume")
    }

    return data
# Out:
# Overwriting stock_data.py

# %%
# %%writefile news_fetcher.py
import requests

API_KEY = "YOUR_GNEWS_API_KEY"

def get_news(company):

    url = f"https://gnews.io/api/v4/search?q={company}&lang=en&apikey={API_KEY}"

    response = requests.get(url)

    articles = response.json()["articles"]

    headlines = []

    for article in articles[:3]:
        headlines.append(article["title"])

    return headlines
# Out:
# Overwriting news_fetcher.py

# %%
# %%writefile ai_summary.py
def generate_summary(stock_data, news):

    script = f"""
Hook:
Today we are looking at this stock update.

Stock Snapshot:
The current stock price is {stock_data['price']}.

What's Happening:
Recent news includes: {news}

Beginner Takeaway:
This information helps beginner investors understand market trends.

Call to Action:
Always research before investing.
"""

    return script
# Out:
# Overwriting ai_summary.py

# %%
# %%writefile video_generator.py
from gtts import gTTS
from moviepy.editor import *

def create_video(script):

    tts = gTTS(script)

    tts.save("voice.mp3")

    audio = AudioFileClip("voice.mp3")

    text = TextClip(script, fontsize=28, size=(720,480), method="caption")

    text = text.set_duration(audio.duration)

    video = text.set_audio(audio)

    video.write_videofile("stock_video.mp4")

    return "stock_video.mp4"
# Out:
# Overwriting video_generator.py

# %%
# %%writefile app.py
import streamlit as st
from stock_data import get_stock_data
from news_fetcher import get_news
from ai_summary import generate_summary
from video_generator import create_video

st.title("AI Stock Market Intelligence Platform")

ticker = st.text_input("Enter NSE Stock Ticker (Example: RELIANCE)")

if st.button("Analyze Stock"):

    stock = get_stock_data(ticker)

    st.subheader("Stock Data")
    st.write(stock)

    news = get_news(ticker)

    st.subheader("Latest News")

    for n in news:
        st.write("-", n)

    script = generate_summary(stock, news)

    st.subheader("Generated Script")

    st.write(script)

    video = create_video(script)

    st.subheader("Generated Video")

    st.video(video)
# Out:
# Overwriting app.py

# %%
# !ls
# Out:
# ai_summary.py  news_fetcher.py	stock_data.py
# app.py	       sample_data	video_generator.py

# %%
# !pip install streamlit pyngrok yfinance gtts moviepy

# %%
# !ngrok config add-authtoken YOUR_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !ls
# Out:
# ai_summary.py  news_fetcher.py	stock_data.py
# app.py	       sample_data	video_generator.py

# %%
# !streamlit run app.py &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !pip install streamlit pyngrok

# %%
# !ls
# Out:
# ai_summary.py  news_fetcher.py	stock_data.py
# app.py	       sample_data	video_generator.py

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !kill -9 $(pgrep streamlit)
# Out:
# kill: usage: kill [-s sigspec | -n signum | -sigspec] pid | jobspec ... or kill -l [sigspec]

# %%
from pyngrok import ngrok
ngrok.kill()

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !pip install streamlit pyngrok yfinance gtts moviepy

# %%
# !pip show pyngrok
# Out:
# Name: pyngrok
# Version: 7.5.1
# Summary: A Python wrapper for ngrok
# Home-page:
# Author:
# Author-email: Alex Laird <contact@alexlaird.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: PyYAML
# Required-by:

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !ls
# Out:
# ai_summary.py  news_fetcher.py	stock_data.py
# app.py	       sample_data	video_generator.py

# %%
# !pip install streamlit pyngrok yfinance gtts moviepy

# %%
# !streamlit run app.py &>/dev/null &

# %%
# !pkill -f streamlit
# !pkill -f ngrok

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !rm -rf /root/.config/ngrok

# %%
# !ngrok config add-authtoken 3B1FMv2N4NdY9OI73ysnUUrephn_3idTHfzFiPGMT9521Muks
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !pkill -f streamlit
# !pkill -f ngrok
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:16:50+0000 lvl=warn msg="Stopping forwarder" name=http-8501-aab29cad-c311-4aca-97a9-f0aeb768735d acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:16:50+0000 lvl=warn msg="Error restarting forwarder" name=http-8501-aab29cad-c311-4aca-97a9-f0aeb768735d err="failed to start tunnel: remote gone away"

# %%
# !streamlit run app.py --server.port 8501 --server.headless true &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.170.3:8501
#
#   Stopping...

# %%
# !pip install streamlit pyngrok gtts moviepy yfinance pillow requests -q

# %%
# !ngrok config add-authtoken 3B1FMv2N4NdY9OI73ysnUUrephn_3idTHfzFiPGMT9521Muks
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import subprocess
import threading
from pyngrok import ngrok
import time

# Streamlit background mein start karo
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8501",
    "--server.headless", "true"
])

time.sleep(3)

# Public URL banao
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# ✅ APP CHAL RAHA HAI!
# 🌐 Yahan click karo: NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !pkill -f streamlit
# !pkill -f ngrok
import time
time.sleep(2)
print("Done")
# Out:
# Done

# %%
import os
files = os.listdir()
print(files)
# Out:
# ['.config', 'stock_data.py', 'video_generator.py', 'ai_summary.py', 'news_fetcher.py', 'app.py', 'sample_data']

# %%
from pyngrok import ngrok
ngrok.kill()
import time
time.sleep(2)
public_url = ngrok.connect(8501)
print("LINK:", public_url)
# Out:
# LINK: NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !pkill -f streamlit
# !pkill -f ngrok
import time
time.sleep(3)

import subprocess
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(6)

from pyngrok import ngrok
ngrok.kill()
time.sleep(2)
url = ngrok.connect(8501)
print("YOUR LINK:", url)
# Out:
# YOUR LINK: NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
news_code = '''
import requests
import xml.etree.ElementTree as ET
from datetime import datetime

def get_news(company, max_articles=5):
    try:
        rss_url = "https://economictimes.indiatimes.com/rssfeedstopstories.cms"
        resp = requests.get(rss_url, timeout=8, headers={"User-Agent": "Mozilla/5.0"})
        root = ET.fromstring(resp.text)
        items = root.findall(".//item")
        articles = []
        for item in items:
            title = item.findtext("title") or ""
            articles.append({
                "title": title,
                "source": "Economic Times",
                "url": item.findtext("link") or "",
                "published": item.findtext("pubDate") or ""
            })
            if len(articles) >= max_articles:
                break
        return articles if articles else [{"title": f"{company} stock in focus today", "source": "FinVise", "url": "", "published": ""}]
    except Exception as e:
        return [{"title": f"{company} stock in focus today", "source": "FinVise", "url": "", "published": ""}]
'''

with open("news_fetcher.py", "w") as f:
    f.write(news_code)

# Fix stock_data.py
stock_code = '''
import yfinance as yf

def get_stock_data(ticker, exchange="NSE"):
    suffix = ".NS" if exchange == "NSE" else ".BO"
    symbol = ticker.upper() + suffix
    try:
        stock = yf.Ticker(symbol)
        info = stock.info
        price = info.get("currentPrice") or info.get("regularMarketPrice")
        return {
            "name": info.get("longName") or ticker,
            "price": round(float(price), 2) if price else "N/A",
            "open": round(float(info.get("open") or 0), 2),
            "high": round(float(info.get("dayHigh") or 0), 2),
            "low": round(float(info.get("dayLow") or 0), 2),
            "volume": int(info.get("volume") or 0),
            "prev_close": round(float(info.get("previousClose") or 0), 2),
            "pe_ratio": info.get("trailingPE", "N/A"),
        }
    except Exception as e:
        return {"name": ticker, "price": "N/A", "open": "N/A", "high": "N/A", "low": "N/A", "volume": 0, "prev_close": "N/A", "pe_ratio": "N/A"}
'''

with open("stock_data.py", "w") as f:
    f.write(stock_code)

print("Both files fixed!")
# Out:
# ✅ Both files fixed!

# %%
# !pkill -f streamlit
import time, subprocess
time.sleep(2)
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(6)
from pyngrok import ngrok
url = ngrok.connect(8501)
print("LINK:", url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:56:55+0000 lvl=warn msg="failed to open private leg" id=b5f0868971ed privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:56:56+0000 lvl=warn msg="failed to open private leg" id=fd17a35cfc19 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:56:56+0000 lvl=warn msg="failed to open private leg" id=e53196ee4b4f privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:56:56+0000 lvl=warn msg="failed to open private leg" id=930170251d10 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:56:58+0000 lvl=warn msg="failed to open private leg" id=cccc9854db2b privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# ...

# %%
app_code = '''
import streamlit as st
from stock_data import get_stock_data
from news_fetcher import get_news
from ai_summary import generate_summary
from video_generator import create_video

st.title("FinVise AI - Indian Stock Intelligence")
ticker = st.text_input("Enter NSE Stock Ticker (Example: RELIANCE)")

if st.button("Analyze Stock"):
    if not ticker:
        st.warning("Please enter a ticker!")
    else:
        ticker = ticker.strip().upper()
        with st.spinner("Fetching stock data..."):
            stock = get_stock_data(ticker, "NSE")
        st.subheader("Stock Data")
        st.write(stock)
        with st.spinner("Fetching news..."):
            news = get_news(ticker)
        st.subheader("Latest News")
        for n in news:
            st.write("*", n["title"])
        with st.spinner("Generating AI script..."):
            script = generate_summary(stock, news, ticker)
        st.subheader("Generated Script")
        st.write(script)
        with st.spinner("Generating video... (takes 30-60 sec)"):
            video_path = create_video(script, ticker)
        if video_path:
            st.video(video_path)
        else:
            st.error("Video generation failed.")
'''
with open("app.py", "w") as f:
    f.write(app_code)
print("app.py done")
# Out:
# app.py done

# %%
video_code = """
import os, re, textwrap
from pathlib import Path
from gtts import gTTS
from moviepy.editor import AudioFileClip, ImageClip, concatenate_videoclips
from PIL import Image, ImageDraw, ImageFont
import numpy as np

TMP = Path("/tmp/finvise")
TMP.mkdir(exist_ok=True)
W, H = 1280, 720

def make_frame(title, body, idx):
    img = Image.new("RGB", (W, H), (10, 14, 26))
    draw = ImageDraw.Draw(img)
    draw.rectangle([(0,0),(W,6)], fill=(0,255,135))
    try:
        font_big = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf", 36)
        font_med = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 28)
        font_sm  = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 18)
    except:
        font_big = font_med = font_sm = ImageFont.load_default()
    draw.text((60, 40), f"[{idx}] {title}", font=font_big, fill=(0,255,135))
    draw.line([(60,90),(W-60,90)], fill=(31,41,55), width=1)
    lines = textwrap.wrap(body, width=60)
    for i, line in enumerate(lines[:10]):
        draw.text((60, 110 + i*46), line, font=font_med, fill=(249,250,251))
    draw.rectangle([(0,H-50),(W,H)], fill=(17,24,39))
    draw.text((60, H-35), "FinVise AI  -  Indian Stock Intelligence", font=font_sm, fill=(107,114,128))
    return np.array(img)

def parse_sections(script):
    parts = [s.strip() for s in re.split(r'\\n\\n+', script) if s.strip()]
    if not parts:
        parts = [script]
    return parts

def create_video(script, ticker="STOCK"):
    try:
        audio_path = str(TMP / "voice.mp3")
        gTTS(text=script, lang="en", tld="co.in").save(audio_path)
        audio = AudioFileClip(audio_path)
        total = audio.duration
        parts = parse_sections(script)
        dur_each = total / len(parts)
        labels = ["HOOK","SNAPSHOT","HAPPENING","TAKEAWAY","CTA"]
        clips = []
        for i, part in enumerate(parts):
            label = labels[i] if i < len(labels) else f"PART {i+1}"
            frame = make_frame(label, part[:300], i+1)
            clips.append(ImageClip(frame).set_duration(dur_each))
        video = concatenate_videoclips(clips, method="compose")
        video = video.set_audio(audio)
        out = str(TMP / f"{ticker}.mp4")
        video.write_videofile(out, fps=24, codec="libx264", audio_codec="aac", logger=None)
        audio.close()
        video.close()
        return out
    except Exception as e:
        print("Video error:", e)
        return None
"""
with open("video_generator.py", "w") as f:
    f.write(video_code)
print("video_generator.py done")
# Out:
# video_generator.py done

# %%
# !pkill -f streamlit
import time, subprocess
time.sleep(2)
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(6)
from pyngrok import ngrok
url = ngrok.connect(8501)
print("LINK:", url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:59:25+0000 lvl=warn msg="failed to open private leg" id=768077529d1e privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:59:25+0000 lvl=warn msg="failed to open private leg" id=1ebd1e4df84c privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:59:27+0000 lvl=warn msg="failed to open private leg" id=a1b11c8154e0 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T09:59:27+0000 lvl=warn msg="failed to open private leg" id=e614ab7ba9d7 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# LINK: NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
import os
import requests

GROQ_API_KEY = os.environ.get("GROQ_API_KEY", "")

def generate_summary(stock_data, news, ticker="STOCK"):
    name  = stock_data.get("name", ticker)
    price = stock_data.get("price", "N/A")
    open_ = stock_data.get("open", "N/A")
    high  = stock_data.get("high", "N/A")
    low   = stock_data.get("low", "N/A")
    news_titles = ", ".join([n["title"] for n in news[:3]])

    if GROQ_API_KEY:
        try:
            headers = {
                "Authorization": f"Bearer {GROQ_API_KEY}",
                "Content-Type": "application/json"
            }
            payload = {
                "model": "llama3-8b-8192",
                "messages": [{
                    "role": "user",
                    "content": f"Write a 90-second beginner-friendly video script for {name} stock. Price: {price}, Open: {open_}, High: {high}, Low: {low}. Recent news: {news_titles}. Use sections: [0-10 sec | HOOK], [10-30 sec | SNAPSHOT], [30-60 sec | HAPPENING], [60-80 sec | TAKEAWAY], [80-90 sec | CTA]. Write in simple spoken English."
                }],
                "max_tokens": 600
            }
            resp = requests.post("https://api.groq.com/openai/v1/chat/completions", headers=headers, json=payload, timeout=20)
            return resp.json()["choices"][0]["message"]["content"].strip()
        except Exception as e:
            print("Groq error:", e)

# %%
# !pkill -f streamlit
import time, subprocess
time.sleep(2)
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(6)
from pyngrok import ngrok
url = ngrok.connect(8501)
print("LINK:", url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:05:36+0000 lvl=warn msg="failed to open private leg" id=4ed2f5930947 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:05:36+0000 lvl=warn msg="failed to open private leg" id=60962f147a7e privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:05:37+0000 lvl=warn msg="failed to open private leg" id=03fbe14f9ca0 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:05:37+0000 lvl=warn msg="failed to open private leg" id=860dcb14116d privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# LINK: NgrokTunnel: "https://tetragonal-subcallosal-elana.ngrok-free.dev" -> "http://localhost:8501"

# %%
import os

code = '''
import os
import requests

GROQ_API_KEY = os.environ.get("GROQ_API_KEY", "")

def generate_summary(stock_data, news, ticker="STOCK"):
    name  = stock_data.get("name", ticker)
    price = stock_data.get("price", "N/A")
    open_ = stock_data.get("open", "N/A")
    high  = stock_data.get("high", "N/A")
    low   = stock_data.get("low", "N/A")
    news_titles = ", ".join([n["title"] for n in news[:3]])
    return f"""[0-10 sec | HOOK]
Did you check {name} today? Here is your 90 second brief!

[10-30 sec | SNAPSHOT]
{name} is trading at Rs {price}. Opened at Rs {open_}, high of Rs {high}, low of Rs {low}.

[30-60 sec | HAPPENING]
Recent news: {news_titles}. Strong volume shows active trader interest in this stock.

[60-80 sec | TAKEAWAY]
For beginners, focus on fundamentals not just daily price movement.

[80-90 sec | CTA]
Subscribe for daily stock briefs and always do your own research before investing!"""
'''

with open("ai_summary.py", "w") as f:
    f.write(code)

os.remove("__pycache__/ai_summary.cpython-312.pyc") if os.path.exists("__pycache__/ai_summary.cpython-312.pyc") else None

print("Done!")
# Out:
# Done!

# %%
# !pkill -f streamlit
import time, subprocess
time.sleep(2)
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(6)
from pyngrok import ngrok
url = ngrok.connect(8501)
print("LINK:", url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:07:41+0000 lvl=warn msg="failed to open private leg" id=eebc3f54bf0d privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:07:41+0000 lvl=warn msg="failed to open private leg" id=dfbafcc82486 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:07:42+0000 lvl=warn msg="failed to open private leg" id=10149dd3f164 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:07:42+0000 lvl=warn msg="failed to open private leg" id=caa77a908c55 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-03-16T10:07:44+0000 lvl=warn msg="failed to open private leg" id=2d4fb69d2e1c privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# ...

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
# !git init
# !git add .
# !git commit -m "FinVise AI - Indian Stock Intelligence Platform"
# !git remote add origin https://github.com/YOUR_USERNAME/finvise-ai.git
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@02d64119ef10.(none)')
# error: src refspec main does not match any
# ...

# %%
# !git config --global user.email "mathankardn@rknec.edu"
# !git config --global user.name "Diksha Mathankar"

# %%
# !git add .
# !git commit -m "FinVise AI - Indian Stock Intelligence Platform"
# !git branch -M main
# !git push -u origin https://github.com/DikshaMathankar/finvise-ai.git
# Out:
# [master (root-commit) c89ea71] FinVise AI - Indian Stock Intelligence Platform
#  31 files changed, 51228 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2026.01.16/14.23.31.981136.log
#  create mode 100644 .config/logs/2026.01.16/14.24.03.314209.log
#  create mode 100644 .config/logs/2026.01.16/14.24.13.071214.log
#  create mode 100644 .config/logs/2026.01.16/14.24.18.954466.log
#  create mode 100644 .config/logs/2026.01.16/14.24.28.646070.log
# ...

# %%
# !git remote remove origin
# !git remote add origin https://github.com/DikshaMathankar/finvise-ai.git
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin
# !git remote add origin https://github.com/DikshaMathankar/finvise-ai.git
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin
# !git remote add origin https://DikshaMathankar:github/DikshaMathankar/finvise-ai.git
# !git push -u origin main
# Out:
# fatal: unable to access 'https://DikshaMathankar:github/DikshaMathankar/finvise-ai.git/': URL using bad/illegal format or missing URL

# %%
import subprocess

token = "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"
repo = f"https://DikshaMathankar:{token}@github.com/DikshaMathankar/finvise-ai.git"

subprocess.run(["git", "remote", "remove", "origin"], capture_output=True)
subprocess.run(["git", "remote", "add", "origin", repo])
result = subprocess.run(["git", "push", "-u", "origin", "main"], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# remote: Permission to DikshaMathankar/finvise-ai.git denied to DikshaMathankar.
# fatal: unable to access 'https://github.com/DikshaMathankar/finvise-ai.git/': The requested URL returned error: 403

# %%
import subprocess

token = "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"
repo = f"https://DikshaMathankar:{token}@github.com/DikshaMathankar/finvise-ai.git"

subprocess.run(["git", "remote", "remove", "origin"], capture_output=True)
subprocess.run(["git", "remote", "add", "origin", repo])
result = subprocess.run(["git", "push", "-u", "origin", "main"], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# remote: Permission to DikshaMathankar/finvise-ai.git denied to DikshaMathankar.
# fatal: unable to access 'https://github.com/DikshaMathankar/finvise-ai.git/': The requested URL returned error: 403

# %%
import shutil
shutil.make_archive("/tmp/finvise-project", "zip", "/content")
print("Done! Download this file:")
print("/tmp/finvise-project.zip")
# Out:
# Done! Download this file:
# /tmp/finvise-project.zip

# %%
from google.colab import files
files.download("/content/app.py")
files.download("/content/stock_data.py")
files.download("/content/news_fetcher.py")
files.download("/content/ai_summary.py")
files.download("/content/video_generator.py")

# %%
from google.colab import files
files.download("/tmp/finvise/RELIANCE.mp4")

# %%
import shutil, os
from google.colab import files

os.makedirs("/tmp/submit", exist_ok=True)

shutil.copy("/content/app.py", "/tmp/submit/")
shutil.copy("/content/stock_data.py", "/tmp/submit/")
shutil.copy("/content/news_fetcher.py", "/tmp/submit/")
shutil.copy("/content/ai_summary.py", "/tmp/submit/")
shutil.copy("/content/video_generator.py", "/tmp/submit/")

shutil.make_archive("/tmp/finvise_submit", "zip", "/tmp/submit")

files.download("/tmp/finvise_submit.zip")
print("ZIP downloading now!")
# Out:
# ZIP downloading now!

# %%
from google.colab import files
files.download("/content/stock_data.py")

# %%
with open("/content/app.py", "r") as f:
    print(f.read())
# Out:
# import streamlit as st
# from stock_data import get_stock_data
# from news_fetcher import get_news
# from ai_summary import generate_summary
# from video_generator import create_video
#
# st.title("FinVise AI - Indian Stock Intelligence")
# ticker = st.text_input("Enter NSE Stock Ticker (Example: RELIANCE)")
#
# if st.button("Analyze Stock"):
#     if not ticker:
#         st.warning("Please enter a ticker!")
#     else:
#         ticker = ticker.strip().upper()
#         with st.spinner("Fetching stock data..."):
#             stock = get_stock_data(ticker, "NSE")
#         st.subheader("Stock Data")
#         st.write(stock)
#         with st.spinner("Fetching news..."):
#             news = get_news(ticker)
#         st.subheader("Latest News")
#         for n in news:
#             st.write("*", n["title"])
#         with st.spinner("Generating AI script..."):
#             script = generate_summary(stock, news, ticker)
#         st.subheader("Generated Script")
# ...

# %%
with open("/content/stock_data.py", "r") as f:
    print(f.read())
# Out:
# import yfinance as yf
#
# def get_stock_data(ticker, exchange="NSE"):
#     suffix = ".NS" if exchange == "NSE" else ".BO"
#     symbol = ticker.upper() + suffix
#     try:
#         stock = yf.Ticker(symbol)
#         info = stock.info
#         price = info.get("currentPrice") or info.get("regularMarketPrice")
#         return {
#             "name": info.get("longName") or ticker,
#             "price": round(float(price), 2) if price else "N/A",
#             "open": round(float(info.get("open") or 0), 2),
#             "high": round(float(info.get("dayHigh") or 0), 2),
#             "low": round(float(info.get("dayLow") or 0), 2),
#             "volume": int(info.get("volume") or 0),
#             "prev_close": round(float(info.get("previousClose") or 0), 2),
#             "pe_ratio": info.get("trailingPE", "N/A"),
#         }
#     except Exception as e:
# ...

# %%
with open("/content/news_fetcher.py", "r") as f:
    print(f.read())
# Out:
# import requests
# import xml.etree.ElementTree as ET
# from datetime import datetime
#
# def get_news(company, max_articles=5):
#     try:
#         rss_url = "https://economictimes.indiatimes.com/rssfeedstopstories.cms"
#         resp = requests.get(rss_url, timeout=8, headers={"User-Agent": "Mozilla/5.0"})
#         root = ET.fromstring(resp.text)
#         items = root.findall(".//item")
#         articles = []
#         for item in items:
#             title = item.findtext("title") or ""
#             articles.append({
#                 "title": title,
#                 "source": "Economic Times",
#                 "url": item.findtext("link") or "",
#                 "published": item.findtext("pubDate") or ""
#             })
#             if len(articles) >= max_articles:
#                 break
#         return articles if articles else [{"title": f"{company} stock in focus today", "source": "FinVise", "url": "", "published": ""}]
#     except Exception as e:
# ...

# %%
with open("/content/ai_summary.py", "r") as f:
    print(f.read())
# Out:
# import os
# import requests
#
# GROQ_API_KEY = os.environ.get("GROQ_API_KEY", "")
#
# def generate_summary(stock_data, news, ticker="STOCK"):
#     name  = stock_data.get("name", ticker)
#     price = stock_data.get("price", "N/A")
#     open_ = stock_data.get("open", "N/A")
#     high  = stock_data.get("high", "N/A")
#     low   = stock_data.get("low", "N/A")
#     news_titles = ", ".join([n["title"] for n in news[:3]])
#     return f"""[0-10 sec | HOOK]
# Did you check {name} today? Here is your 90 second brief!
#
# [10-30 sec | SNAPSHOT]
# {name} is trading at Rs {price}. Opened at Rs {open_}, high of Rs {high}, low of Rs {low}.
#
# [30-60 sec | HAPPENING]
# Recent news: {news_titles}. Strong volume shows active trader interest in this stock.
#
# [60-80 sec | TAKEAWAY]
# For beginners, focus on fundamentals not just daily price movement.
#
# [80-90 sec | CTA]
# Subscribe for daily stock briefs and always do your own research before investing!"""

# %%
with open("/content/video_generator.py", "r") as f:
    print(f.read())
# Out:
# import os, re, textwrap
# from pathlib import Path
# from gtts import gTTS
# from moviepy.editor import AudioFileClip, ImageClip, concatenate_videoclips
# from PIL import Image, ImageDraw, ImageFont
# import numpy as np
#
# TMP = Path("/tmp/finvise")
# TMP.mkdir(exist_ok=True)
# W, H = 1280, 720
#
# def make_frame(title, body, idx):
#     img = Image.new("RGB", (W, H), (10, 14, 26))
#     draw = ImageDraw.Draw(img)
#     draw.rectangle([(0,0),(W,6)], fill=(0,255,135))
#     try:
#         font_big = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf", 36)
#         font_med = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 28)
#         font_sm  = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 18)
#     except:
#         font_big = font_med = font_sm = ImageFont.load_default()
#     draw.text((60, 40), f"[{idx}] {title}", font=font_big, fill=(0,255,135))
#     draw.line([(60,90),(W-60,90)], fill=(31,41,55), width=1)
# ...
